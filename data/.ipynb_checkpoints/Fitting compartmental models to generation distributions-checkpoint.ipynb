# %% [markdown]
# # Fitting compartmental models to generation time distributions

# %%
using OrdinaryDiffEq,Plots,Distributions,SparseArrays,Distances,QuadGK

# %%
function create_rate_matrix(p)
    σ₁, σ₂, γ,β = p
    Q = spzeros(4,4)
    Q[2,1] = σ₁ #E->P
    Q[3,2] = σ₂ #P->I
    Q[4,3] = γ #I->R
    for k = 1:4
        Q[k,k] = -sum(Q[:,k])
    end
    return Q
end
# Out:
# create_rate_matrix (generic function with 1 method)

# %%
p = [1/3.1,1/2,1/7.,2/9.]
Q = create_rate_matrix(p)
L = DiffEqArrayOperator(Q)
# Out:
# DiffEqArrayOperator{Float64,SparseMatrixCSC{Float64,Int64},typeof(DiffEqBase.DEFAULT_UPDATE_FUNC)}(
#   [1, 1]  =  -0.322581
#   [2, 1]  =  0.322581
#   [2, 2]  =  -0.5
#   [3, 2]  =  0.5
#   [3, 3]  =  -0.142857
#   [4, 3]  =  0.142857, DiffEqBase.DEFAULT_UPDATE_FUNC)

# %%
# function f(du,u,p,t)
#     du .= Q*u
# end
u0 = [1.,0.,0.,0.]
tspan = (0,80.)
ff = ODEFunction(L,syms = [:prob_E,:prob_P,:prob_I,:prob_R])
prob = ODEProblem(ff,u0,tspan,p)
@time sol = solve(prob,Tsit5())




plot(sol)
# Out:
#   0.000118 seconds (395 allocations: 41.453 KiB)

# %%
function generation_time_from_sol(sol)
    p = sol.prob.p
    σ₁, σ₂, γ,β = p
    R₀ = β*(0.1*(1/σ₂) + (1/γ) )
    return t -> sum(sol(t).*[0.,0.1*β,β,0])/R₀
end
# Out:
# generation_time_from_sol (generic function with 1 method)

# %%
w_t = generation_time_from_sol(sol)
plt = plot(w_t,0.,90.,lab = "generation time distribution")
# d_gen_time = Weibull(2.826,5.665)
# fitted_gen_time = [pdf(d_gen_time,t) for t in 0:0.1:90]
# plot!(plt,0:0.1:90.,fitted_gen_time,lab = "Ferreti et al fit")

# %%
quadgk(w_t,0.,90.)
# Out:
# (0.999992920837787, 1.458698504995244e-8)

# %%
#discounted version
function discounted_w_t(w_t,λ)
    norm_const = quadgk(t-> w_t(t)*exp(-λ*t),0.,100.)[1]
    dw_t(t) = w_t(t)*exp(-λ*t)/norm_const
    return dw_t
end
λ = 0.01
dw_t = discounted_w_t(w_t,λ)
plt = plot(dw_t,0.,20.,lab = "Discounted generation time distribution (dis. rate = $λ)")
# Out:
# UndefVarError: T not defined
#
# Stacktrace:
#  [1] (::var"#dw_t#36"{var"#11#12"{ODESolution{Float64,2,Array{Array{Float64,1},1},Nothing,Nothing,Array{Float64,1},Array{Array{Array{Float64,1},1},1},ODEProblem{Array{Float64,1},Tuple{Float64,Float64},true,Array{Float64,1},ODEFunction{true,DiffEqArrayOperator{Float64,SparseMatrixCSC{Float64,Int64},typeof(DiffEqBase.DEFAULT_UPDATE_FUNC)},LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Array{Symbol,1},Nothing},Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}},DiffEqBase.StandardODEProblem},Tsit5,OrdinaryDiffEq.InterpolationData{ODEFunction{true,DiffEqArrayOperator{Float64,SparseMatrixCSC{Float64,Int64},typeof(DiffEqBase.DEFAULT_UPDATE_FUNC)},LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Array{Symbol,1},Nothing},Array{Array{Float64,1},1},Array{Float64,1},Array{Array{Array{Float64,1},1},1},OrdinaryDiffEq.Tsit5Cache{Array{Float64,1},Array{Float64,1},Array{Float64,1},OrdinaryDiffEq.Tsit5ConstantCache{Float64,Float64}}},DiffEqBase.DEStats},Float64,Float64},Float64,Float64})(::Float64) at ./In[45]:5
#  [2] (::Base.var"#56#57"{RecipesPipeline.var"#11#12"{Symbol},var"#dw_t#36"{var"#11#12"{ODESolution{Float64,2,Array{Array{Float64,1},1},Nothing,Nothing,Array{Float64,1},Array{Array{Array{Float64,1},1},1},ODEProblem{Array{Float64,1},Tuple{Float64,Float64},true,Array{Float64,1},ODEFunction{true,DiffEqArrayOperator{Float64,SparseMatrixCSC{Float64,Int64},typeof(DiffEqBase.DEFAULT_UPDATE_FUNC)},LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Array{Symbol,1},Nothing},Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}},DiffEqBase.StandardODEProblem},Tsit5,OrdinaryDiffEq.InterpolationData{ODEFunction{true,DiffEqArrayOperator{Float64,SparseMatrixCSC{Float64,Int64},typeof(DiffEqBase.DEFAULT_UPDATE_FUNC)},LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Array{Symbol,1},Nothing},Array{Array{Float64,1},1},Array{Float64,1},Array{Array{Array{Float64,1},1},1},OrdinaryDiffEq.Tsit5Cache{Array{Float64,1},Array{Float64,1},Array{Float64,1},OrdinaryDiffEq.Tsit5ConstantCache{Float64,Float64}}},DiffEqBase.DEStats},Float64,Float64},Float64,Float64}})(::Float64) at ./operators.jl:873 (repeats 2 times)
#  [3] (::PlotUtils.var"#27#29"{Base.var"#56#57"{Base.var"#56#57"{RecipesPipeline.var"#11#12"{Symbol},var"#dw_t#36"{var"#11#12"{ODESolution{Float64,2,Array{Array{Float64,1},1},Nothing,Nothing,Array{Float64,1},Array{Array{Array{Float64,1},1},1},ODEProblem{Array{Float64,1},Tuple{Float64,Float64},true,Array{Float64,1},ODEFunction{true,DiffEqArrayOperator{Float64,SparseMatrixCSC{Float64,Int64},typeof(DiffEqBase.DEFAULT_UPDATE_FUNC)},LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Array{Symbol,1},Nothing},Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}},DiffEqBase.StandardODEProblem},Tsit5,OrdinaryDiffEq.InterpolationData{ODEFunction{true,DiffEqArrayOperator{Float64,SparseMatrixCSC{Float64,Int64},typeof(DiffEqBase.DEFAULT_UPDATE_FUNC)},LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Array{Symbol,1},Nothing},Array{Array{Float64,1},1},Array{Float64,1},Array{Array{Array{Float64,1},1},1},OrdinaryDiffEq.Tsit5Cache{Array{Float64,1},Array{Float64,1},Array{Float64,1},OrdinaryDiffEq.Tsit5ConstantCache{Float64,Float64}}},DiffEqBase.DEStats},Float64,Float64},Float64,Float64}},RecipesPipeline.var"#13#14"{Symbol}}})(::Float64) at /Users/Sam/.julia/packages/PlotUtils/T5XYM/src/adapted_grid.jl:48
#  [4] _broadcast_getindex at ./broadcast.jl:630 [inlined]
#  [5] getindex at ./broadcast.jl:563 [inlined]
#  [6] copy at ./broadcast.jl:853 [inlined]
#  [7] materialize at ./broadcast.jl:819 [inlined]
#  [8] #adapted_grid#26(::Int64, ::typeof(adapted_grid), ::Base.var"#56#57"{Base.var"#56#57"{RecipesPipeline.var"#11#12"{Symbol},var"#dw_t#36"{var"#11#12"{ODESolution{Float64,2,Array{Array{Float64,1},1},Nothing,Nothing,Array{Float64,1},Array{Array{Array{Float64,1},1},1},ODEProblem{Array{Float64,1},Tuple{Float64,Float64},true,Array{Float64,1},ODEFunction{true,DiffEqArrayOperator{Float64,SparseMatrixCSC{Float64,Int64},typeof(DiffEqBase.DEFAULT_UPDATE_FUNC)},LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Array{Symbol,1},Nothing},Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}},DiffEqBase.StandardODEProblem},Tsit5,OrdinaryDiffEq.InterpolationData{ODEFunction{true,DiffEqArrayOperator{Float64,SparseMatrixCSC{Float64,Int64},typeof(DiffEqBase.DEFAULT_UPDATE_FUNC)},LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Array{Symbol,1},Nothing},Array{Array{Float64,1},1},Array{Float64,1},Array{Array{Array{Float64,1},1},1},OrdinaryDiffEq.Tsit5Cache{Array{Float64,1},Array{Float64,1},Array{Float64,1},OrdinaryDiffEq.Tsit5ConstantCache{Float64,Float64}}},DiffEqBase.DEStats},Float64,Float64},Float64,Float64}},RecipesPipeline.var"#13#14"{Symbol}}, ::Tuple{Float64,Float64}) at /Users/Sam/.julia/packages/PlotUtils/T5XYM/src/adapted_grid.jl:59
#  [9] adapted_grid(::Function, ::Tuple{Float64,Float64}) at /Users/Sam/.julia/packages/PlotUtils/T5XYM/src/adapted_grid.jl:15
#  [10] _scaled_adapted_grid(::Function, ::Symbol, ::Symbol, ::Float64, ::Float64) at /Users/Sam/.julia/packages/RecipesPipeline/5b2IP/src/user_recipe.jl:307
#  [11] macro expansion at /Users/Sam/.julia/packages/RecipesPipeline/5b2IP/src/user_recipe.jl:286 [inlined]
#  [12] apply_recipe(::Dict{Symbol,Any}, ::Function, ::Float64, ::Float64) at /Users/Sam/.julia/packages/RecipesBase/jcXIg/src/RecipesBase.jl:281
#  [13] _process_userrecipes!(::Plots.Plot{Plots.GRBackend}, ::Dict{Symbol,Any}, ::Tuple{var"#dw_t#36"{var"#11#12"{ODESolution{Float64,2,Array{Array{Float64,1},1},Nothing,Nothing,Array{Float64,1},Array{Array{Array{Float64,1},1},1},ODEProblem{Array{Float64,1},Tuple{Float64,Float64},true,Array{Float64,1},ODEFunction{true,DiffEqArrayOperator{Float64,SparseMatrixCSC{Float64,Int64},typeof(DiffEqBase.DEFAULT_UPDATE_FUNC)},LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Array{Symbol,1},Nothing},Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}},DiffEqBase.StandardODEProblem},Tsit5,OrdinaryDiffEq.InterpolationData{ODEFunction{true,DiffEqArrayOperator{Float64,SparseMatrixCSC{Float64,Int64},typeof(DiffEqBase.DEFAULT_UPDATE_FUNC)},LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Array{Symbol,1},Nothing},Array{Array{Float64,1},1},Array{Float64,1},Array{Array{Array{Float64,1},1},1},OrdinaryDiffEq.Tsit5Cache{Array{Float64,1},Array{Float64,1},Array{Float64,1},OrdinaryDiffEq.Tsit5ConstantCache{Float64,Float64}}},DiffEqBase.DEStats},Float64,Float64},Float64,Float64},Float64,Float64}) at /Users/Sam/.julia/packages/RecipesPipeline/5b2IP/src/user_recipe.jl:35
#  [14] recipe_pipeline!(::Plots.Plot{Plots.GRBackend}, ::Dict{Symbol,Any}, ::Tuple{var"#dw_t#36"{var"#11#12"{ODESolution{Float64,2,Array{Array{Float64,1},1},Nothing,Nothing,Array{Float64,1},Array{Array{Array{Float64,1},1},1},ODEProblem{Array{Float64,1},Tuple{Float64,Float64},true,Array{Float64,1},ODEFunction{true,DiffEqArrayOperator{Float64,SparseMatrixCSC{Float64,Int64},typeof(DiffEqBase.DEFAULT_UPDATE_FUNC)},LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Array{Symbol,1},Nothing},Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}},DiffEqBase.StandardODEProblem},Tsit5,OrdinaryDiffEq.InterpolationData{ODEFunction{true,DiffEqArrayOperator{Float64,SparseMatrixCSC{Float64,Int64},typeof(DiffEqBase.DEFAULT_UPDATE_FUNC)},LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Array{Symbol,1},Nothing},Array{Array{Float64,1},1},Array{Float64,1},Array{Array{Array{Float64,1},1},1},OrdinaryDiffEq.Tsit5Cache{Array{Float64,1},Array{Float64,1},Array{Float64,1},OrdinaryDiffEq.Tsit5ConstantCache{Float64,Float64}}},DiffEqBase.DEStats},Float64,Float64},Float64,Float64},Float64,Float64}) at /Users/Sam/.julia/packages/RecipesPipeline/5b2IP/src/RecipesPipeline.jl:68
#  [15] _plot!(::Plots.Plot{Plots.GRBackend}, ::Dict{Symbol,Any}, ::Tuple{var"#dw_t#36"{var"#11#12"{ODESolution{Float64,2,Array{Array{Float64,1},1},Nothing,Nothing,Array{Float64,1},Array{Array{Array{Float64,1},1},1},ODEProblem{Array{Float64,1},Tuple{Float64,Float64},true,Array{Float64,1},ODEFunction{true,DiffEqArrayOperator{Float64,SparseMatrixCSC{Float64,Int64},typeof(DiffEqBase.DEFAULT_UPDATE_FUNC)},LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Array{Symbol,1},Nothing},Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}},DiffEqBase.StandardODEProblem},Tsit5,OrdinaryDiffEq.InterpolationData{ODEFunction{true,DiffEqArrayOperator{Float64,SparseMatrixCSC{Float64,Int64},typeof(DiffEqBase.DEFAULT_UPDATE_FUNC)},LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Array{Symbol,1},Nothing},Array{Array{Float64,1},1},Array{Float64,1},Array{Array{Array{Float64,1},1},1},OrdinaryDiffEq.Tsit5Cache{Array{Float64,1},Array{Float64,1},Array{Float64,1},OrdinaryDiffEq.Tsit5ConstantCache{Float64,Float64}}},DiffEqBase.DEStats},Float64,Float64},Float64,Float64},Float64,Float64}) at /Users/Sam/.julia/packages/Plots/JKY3H/src/plot.jl:167
#  [16] #plot#124(::Base.Iterators.Pairs{Symbol,String,Tuple{Symbol},NamedTuple{(:lab,),Tuple{String}}}, ::typeof(plot), ::Function, ::Vararg{Any,N} where N) at /Users/Sam/.julia/packages/Plots/JKY3H/src/plot.jl:57
#  [17] (::RecipesBase.var"#kw##plot")(::NamedTuple{(:lab,),Tuple{String}}, ::typeof(plot), ::Function, ::Float64, ::Vararg{Float64,N} where N) at ./none:0
#  [18] top-level scope at In[45]:15

# %%
function rel_entropy(w_t)
    p_w = [w_t(t) for t in 0.:0.1:20. ]
    return  0.1*sum([p_w.*(log.(p_w) .- log.(fitted_gen_time))])
end
log.([w_t(t) for t in 0.:0.1:20. ]) .- log.(fitted_gen_time)
# Out:
# 201-element Array{Float64,1}:
#  NaN
#   -0.4735881332254639
#   -0.2203776401809865
#   -0.05523887887081802
#    0.06301070775347828
#    0.150684004616096
#    0.2165187380553233
#    0.2658887023794696
#    0.30240594797514797
#    0.3286191804655667
#    0.3464284686639614
#    0.3572600076831911
#    0.36225744295914586
#    ⋮
#   22.391979151903932
#   22.801453197320306
#   23.21534441482065
#   23.63367094347061
#   24.056448425094104
#   24.48369561359046
#   24.91543269091442
#   25.35167963952102
#   25.792456232632304
#   26.237782025734383
#   26.687676349552557
#   27.142158304775336

# %%
kl_divergence([w_t(t) for t in 0.:0.1:30. ],[pdf(d_gen_time,t) for t in 0:0.1:30])
# Out:
# 7.368925740490218
